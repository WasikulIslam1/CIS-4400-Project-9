# %%
import pandas as pd
import json

# Load JSON data
with open('/Users/nicholasnoto/Desktop/CIS 4400/Group Project/school_digger_AK_NE.json', 'r') as f:
    data1 = json.load(f)
with open('/Users/nicholasnoto/Desktop/CIS 4400/Group Project/SchoolDigger_NH_WY.json', 'r') as f:
    data2 = json.load(f)

# Convert to DataFrames
df1 = pd.DataFrame(data1)
df2 = pd.DataFrame(data2)

# Combine DataFrames
combined_df = pd.concat([df1, df2], ignore_index=True)

# Display the DataFrame
combined_df
# Out:
#                                                       0   \
# 0      {'Name': 'Central Middle School of Science', '...
# 1      {'Name': 'Chinook Elementary', 'City': 'Anchor...
# 2      {'Name': 'Family Partnership Charter School', ...
# 3      {'Name': 'Alaska State School for Deaf and Har...
# 4      {'Name': 'Ursa Major Elementary', 'City': 'Elm...
# ...                                                  ...
# 60951                                               None
# 60952                                               None
# 60953  {'Name': 'Thayne Elementary', 'City': 'Thayne'...
# 60954                                               None
# 60955  {'Name': 'Alta Elementary', 'City': 'Alta', 'S...
#
#                                                       1   \
# 0      {'Name': 'Chugach Optional Elementary', 'City'...
# 1      {'Name': 'Dimond High School', 'City': 'Anchor...
# 2      {'Name': 'Frontier Charter School', 'City': 'A...
# ...
